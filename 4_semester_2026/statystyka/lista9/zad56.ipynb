# %%
import numpy as np
import matplotlib.pyplot as plt

rng = np.random.default_rng (1)
x1 = rng.uniform(0, 1, size =100)
x2 = 0.5 * x1 + rng.normal(size =100) / 10
y = 2 + 2 * x1 + 0.3 * x2 + rng.normal(size =100)
print("Y=2+2*x1+0.3*x2+")
print("theta0 = 2, theta1=2, theta2=0.3")
# Out:
# Y=2+2*x1+0.3*x2+
# theta0 = 2, theta1=2, theta2=0.3

# %%
plt.scatter(x1,x2)
plt.xlabel("x1")
plt.ylabel("x2")
plt.title("Korelacja x1 i x2")
plt.show()

# %%
import pandas as pd
import statsmodels.api as sm

X_c = np.column_stack((x1, x2))
X_c = sm.add_constant(X_c) 

model_c = sm.OLS(y, X_c).fit()

print(model_c.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.303
# Model:                            OLS   Adj. R-squared:                  0.288
# Method:                 Least Squares   F-statistic:                     21.27
# Date:                Tue, 12 May 2026   Prob (F-statistic):           2.13e-08
# Time:                        16:12:37   Log-Likelihood:                -139.42
# No. Observations:                 101   AIC:                             284.8
# Df Residuals:                      98   BIC:                             292.7
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          1.8926      0.198      9.574      0.000       1.500       2.285
# ...

# %%
X_d = sm.add_constant(x1)

model_d = sm.OLS(y, X_d).fit()

print(model_d.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.258
# Model:                            OLS   Adj. R-squared:                  0.250
# Method:                 Least Squares   F-statistic:                     34.41
# Date:                Tue, 12 May 2026   Prob (F-statistic):           5.92e-08
# Time:                        16:12:26   Log-Likelihood:                -142.56
# No. Observations:                 101   AIC:                             289.1
# Df Residuals:                      99   BIC:                             294.4
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          1.9308      0.202      9.545      0.000       1.529       2.332
# ...

# %%
X_e = sm.add_constant(x2)

model_e = sm.OLS(y, X_e).fit()

print(model_e.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.227
# Model:                            OLS   Adj. R-squared:                  0.219
# Method:                 Least Squares   F-statistic:                     28.75
# Date:                Tue, 12 May 2026   Prob (F-statistic):           5.48e-07
# Time:                        16:12:02   Log-Likelihood:                -140.10
# No. Observations:                 100   AIC:                             284.2
# Df Residuals:                      98   BIC:                             289.4
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          2.1696      0.173     12.505      0.000       1.825       2.514
# ...

# %%
x1 = np.concatenate([x1, [0.1]])
x2 = np.concatenate([x2, [0.8]])
y = np.concatenate([y, [6]])

# %%
X_f1 = np.column_stack((x1, x2))
X_f1 = sm.add_constant(X_f1) 

model_f1 = sm.OLS(y, X_f1).fit()

print(model_f1.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.303
# Model:                            OLS   Adj. R-squared:                  0.288
# Method:                 Least Squares   F-statistic:                     21.27
# Date:                Tue, 12 May 2026   Prob (F-statistic):           2.13e-08
# Time:                        16:12:10   Log-Likelihood:                -139.42
# No. Observations:                 101   AIC:                             284.8
# Df Residuals:                      98   BIC:                             292.7
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          1.8926      0.198      9.574      0.000       1.500       2.285
# ...

# %%
X_f2 = sm.add_constant(x1)

model_f2 = sm.OLS(y, X_f2).fit()

print(model_f2.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.072
# Model:                            OLS   Adj. R-squared:                  0.063
# Method:                 Least Squares   F-statistic:                     7.996
# Date:                Mon, 11 May 2026   Prob (F-statistic):            0.00563
# Time:                        19:41:05   Log-Likelihood:                -165.99
# No. Observations:                 105   AIC:                             336.0
# Df Residuals:                     103   BIC:                             341.3
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          2.5474      0.230     11.074      0.000       2.091       3.004
# ...

# %%
X_f3=sm.add_constant(x2)
model_f3=sm.OLS(y,X_f3).fit()
print(model_f2.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.072
# Model:                            OLS   Adj. R-squared:                  0.063
# Method:                 Least Squares   F-statistic:                     7.996
# Date:                Mon, 11 May 2026   Prob (F-statistic):            0.00563
# Time:                        19:41:51   Log-Likelihood:                -165.99
# No. Observations:                 105   AIC:                             336.0
# Df Residuals:                     103   BIC:                             341.3
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          2.5474      0.230     11.074      0.000       2.091       3.004
# ...
